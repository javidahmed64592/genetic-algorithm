# %% [markdown]
# # **Genetic Algorithm - Phrase Solver**

# %% [markdown]
# This notebook shows how to use the genetic algorithm classes to create a training scenario.
# It will demonstrate how a genetic algorithm can be used to generate a specific sentence.

# %% [markdown]
# For a sentence of length $L$ constructed from $N_C$ possible characters, the number of permutations of possible sentences is given by $(N_C)^L$.
#
# If $N_P$ sentences are created each generation, it would take $\frac{(N_C)^L}{N_P}$ generations on average to create a specific sentence.
# This number grows large quickly, and so this genetic algorithm aims to implement a more efficient algorithm to find a solution.

# %% [markdown]
# ## Code Implementation

# %% [markdown]
# ### Libraries and Helper Functions

# %% [markdown]
# To create the training scenario, we will need to import `GeneticAlgorithm` and `Member`. We will use class inheritance to set things up.

# %%
from __future__ import annotations

import logging

import numpy as np

from genetic_algorithm.ga import GeneticAlgorithm
from genetic_algorithm.member import Member

logging.basicConfig(format="%(asctime)s %(message)s", datefmt="[%d-%m-%Y|%H:%M:%S]", level=logging.INFO)
logger = logging.getLogger(__name__)
rng = np.random.default_rng()

# %% [markdown]
# ### Creating Classes from Member and GeneticAlgorithm

# %% [markdown]
# The following class is used to represent an individual which has genetic information. In this case, the genes are different characters, and a sequence of these genes is a chromosome which can be mixed between individuals each generation. The individuals with better chromosomes (i.e. a higher fitness score) are more likely to reproduce and pass on their genes to future generations.
#
# Their fitnesses are calculated by checking the number of characters in their chromosome which match a specified phrase and then squaring that number.
#
# To crossover two chromosomes to construct a new sequence, genes are taken randomly from the two with equal probability, and there is also a chance for the gene to mutate and choose a random character.
#
# Configuring:
# - `Member._chromosome`
# - `Member._new_chromosome`
# - `Member.fitness`
# - `Member.crossover()`

# %%
class PhraseSolverMember(Member):
    """Member to use in PhraseSolver app."""

    def __init__(self, length: int, gene_pool: list[str]) -> None:
        """Initialise PhraseSolverMember with length of phrase and gene pool.

        :param int length:
            Length of the phrase to solve
        :param list[str] gene_pool:
            List of possible genes to use in the chromosome
        """
        super().__init__()
        self._length = length
        self._gene_pool = gene_pool
        self._chromosome = "".join([self.random_char for _ in range(self._length)])

    @property
    def random_char(self) -> str:
        """Return a random gene from the possible genes."""
        _choice: str = rng.choice(self._gene_pool)
        return _choice

    @property
    def fitness(self) -> int:
        """Return member fitness."""
        return self._score**2

    def calculate_score(self, phrase: str) -> None:
        """Calculate the member's score based on the provided phrase.

        :param str phrase:
            Phrase to compare the member's chromosome against
        """
        self._score = sum([self._chromosome[i] == phrase[i] for i in range(self._length)])

    def crossover(self, parent_a: Member, parent_b: Member, mutation_rate: int) -> None:
        """Crossover the chromosomes of two parents to create a new chromosome.

        :param Member parent_a:
            First parent member
        :param Member parent_b:
            Second parent member
        :param int mutation_rate:
            Mutation rate as a percentage (0-100) for the crossover
        """
        def _choose_gene(roll: int, i: int) -> str:
            # Half of the genes will come from parentA
            if roll < (100 - mutation_rate) / 2:
                return parent_a._chromosome[i]
            # Half of the genes will come from parentB
            if roll < (100 - mutation_rate):
                return parent_b._chromosome[i]

            # Chance for a random gene to be selected
            return self.random_char

        prob_array = rng.integers(0, 100, size=self._length)
        indices = np.arange(self._length)
        vectorized_choose_gene = np.vectorize(_choose_gene)
        self._new_chromosome = "".join(vectorized_choose_gene(prob_array, indices))

# %% [markdown]
# The next class is used to generate a population of the members belonging to the above class. It is also used to run the algorithm.
#
# Each generation, the fitnesses of each member is evaluated.
# The highest fitness is used to normalise the fitnesses to be in the range [0, 1].
# The normalised fitnesses are used to select parents for the next generation of individuals via the Rejection Sampling technique:
#
# 1) Select a random member from the population
# 2) Generate a random number between 0 and 1
# 3) If this number is less than than the normalised fitness of the parent, the parent is selected. Otherwise, select a new random member and generate a new number.
#
# This is a memory efficient way of making members with higher fitnesses more likely to reproduce.
# For each individual of the new generation, two different parents are selected this way.
# Their chromosomes are mixed to generate a new sequence for that individual.
#
# The program terminates when a member of the population has a chromosome which completely matches the specified phrase.
#
# Configuring:
# - `GeneticAlgorithm._population`
# - `GeneticAlgorithm._evaluate()`
# - `GeneticAlgorithm._analyse()`

# %%
class PhraseSolver(GeneticAlgorithm):
    """Simple app to use genetic algorithms to solve an alphanumeric phrase."""

    def __init__(self, members: list[PhraseSolverMember], mutation_rate: int) -> None:
        """Initialise PhraseSolver app.

        :param list[PhraseSolverMember] members:
            List of members to use in the population
        :param int mutation_rate:
            Mutation rate for members
        """
        super().__init__(members, mutation_rate)
        self._phrase: str

    @classmethod
    def create_and_run(
        cls, population_size: int, mutation_rate: int, phrase: str, mem_genes: list[str]
    ) -> PhraseSolver:
        """Create app and run genetic algorithm.

        :param int population_size:
            Size of the population to create
        :param int mutation_rate:
            Mutation rate for the members
        :param str phrase:
            Phrase to solve using the genetic algorithm
        :param list[str] mem_genes:
            List of possible genes to use in the chromosome
        :return PhraseSolver:
            Instance of PhraseSolver with the genetic algorithm run
        """
        ga = cls([PhraseSolverMember(len(phrase), mem_genes) for _ in range(population_size)], mutation_rate)
        ga._phrase = phrase
        logger.info(ga)
        ga.run()
        return ga

    def _evaluate(self) -> None:
        """Evaluate the population."""
        for _member in self._population._members:
            _member.calculate_score(self._phrase)
        self._population.evaluate()

    def _analyse(self) -> None:
        """Analyse best member's chromosome."""
        _gen_text = f"Generation {self._generation:>4}:"

        # Correct phrase found so break out of the loop
        if self._population.best_chromosome == self._phrase:
            logger.info("%s %s \t|| Solved!", _gen_text, self._population.best_chromosome)
            self._running = False
            return

        # Return the closest match and its associated fitness then evolve.
        logger.info(
            "%s %s \t|| Max Fitness: %d",
            _gen_text,
            self._population.best_chromosome,
            self._population.best_fitness,
        )

# %% [markdown]
# ### Running the Algorithm

# %% [markdown]
# The possible genes an individual's chromosome can contain are provided as a list.
# The population size and mutation rate is then defined.
# A phrase is also chosen for the population members to guess.

# %%
population_size = 200
mutation_rate = 3
phrase = "I am a genetic algorithm!"
gene_pool = list("0123456789 abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ.,!?")

# %% [markdown]
# Each generation, the best guess will be printed and until eventually it has converged on the specified phrase.

# %%
ga = PhraseSolver.create_and_run(population_size, mutation_rate, phrase, gene_pool)
# Out:
# [19-06-2025|23:49:42] Population Size: 200
# Mutation Rate: 3
# [19-06-2025|23:49:42] Generation    1: c6WZr?hgF5,edKa8lz0TLq3Sh 	|| Max Fitness: 4
# [19-06-2025|23:49:42] Generation    2: yjDp!EfgeyEoSL aa,R1bVCoI 	|| Max Fitness: 16
m! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   37: I3amXa genZ8hc algoriphm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   38: IFam a genZ5zc algoriqhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   39: IFam a genL5Pc algorvqhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   40: IFam a geniiYc algoriqhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   41: IFax a genL2Dc algoriwhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   42: IFam a gedHunc algoriOhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   43: I3am algenOiPc algorifhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   44: ITam a ge!5iYc algoriphm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   45: I7am a gen1i c algoriphm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   46: ILam a gen1?a. algoriqhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   47: Ixam a ge!1vzc algoriwhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   48: Ixam a gen7oPc vlgoriHhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   49: ITam a genLN c algoriWhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   50: Ioam a genriIc algoriAhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   51: Ioam a genriIc algoriAhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   52: Ioam aCgenrvPc algoriqhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   53: Iiam a geI7Uic algoriWhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   54: Ixam a genrUic algoriqhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   55: I2amsa genxo c algoriOhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   56: 5iam a genxtzc aSgori5hm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   57: I6am a genxv cfalgorixhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   58: I3am a genasic awgoriphm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   59: I7am a genZWYc algorichm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   60: I3am a genLvic alSorichm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   61: I7am a genxiic algoriAhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   62: I3am a genxiic algorixhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   63: I7am a genZiic awZoriqhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   64: I7am A genZtVc alg riOhm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   65: Ixam a genhtZc algorichm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   66: Ixam a genhtKc al.orichm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   67: Ixam a genhtKc algoriWhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   68: Ixam a genLtic algoribhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:43] Generation   69: Ioam a genDtZc algor1Ahm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   70: I3am y genxtic algoGifhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   71: I4am Z gen3tic alLor1Ohm! 	|| Max Fitness: 361
# [19-06-2025|23:49:43] Generation   72: IZamMa genOtZc algoriqhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   73: IZ9m a genxlic algoriqhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   74: IZam a gen6tvc algoriOhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   75: I6am aggen6Hic algoriyhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   76: IyaW a genat7c algorirhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   77: I3am a gen1tic algoriqhbr 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   78: I am a genxuic algoTiuhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   79: Iyam a genxu c algorirhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   80: I3am a genxiic algorirhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   81: Ibam a genZtic algoriOfm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   82: I?am a genytic algorizhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:43] Generation   83: I2am a genxhNc algorirhm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   84: I am a gknhiic algorizhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   85: IYam a genZtVc algorizhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   86: Iham a genZhic algorP6hm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   87: Ibam a genxtic algoriXNmz 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   88: IZam aNgenxtic algoriXXm! 	|| Max Fitness: 400
# [19-06-2025|23:49:43] Generation   89: I9am v ge,htic algorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   90: I3am ajgenPtic algoritQm! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   91: IYam a genTtic algoBithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:43] Generation   92: IYam a genTtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:43] Generation   93: IYam a genTtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:43] Generation   94: IYam aMgenTtic algorit0m! 	|| Max Fitness: 441
# [19-06-2025|23:49:43] Generation   95: Ibam a ganhtic algorZthm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation   96: I3mm a genxtic algoriqhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation   97: I?am x genxticmalgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation   98: Ipam a genhticcalgojithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation   99: I3am a gex0tcc algoritim! 	|| Max Fitness: 400
# [19-06-2025|23:49:44] Generation  100: IsamFa gen!tic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  101: IZam a genLtic azgorkthm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  102: I,amUa gen!tic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  103: I?am a genVtic aJCorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  104: I?am a gendticcalgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  105: IAam a genUtrc algoriqhm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  106: Iham a genxtic algoOithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  107: Iyam F genUtic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  108: Iyam a genUtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  109: Ihat a gendtic algor1thm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  110: I3am a geiytrc algorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  111: Iyam a genhtic algoriqhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  112: IBam a genxtic algoriuhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  113: I?am a gendtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  114: I0am a gendtic algorithme 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  115: Iyam a genctic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  116: IBam a genytic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  117: I.am a gendtiZ 4lgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  118: I0am a gendtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  119: IBam a gendtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  120: IBam a gendticvalgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  121: I7am a ZenCtic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  122: I0am a genUtic algoriBhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  123: I?am a genatic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  124: I6am a genytic aMgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  125: I0am a genUtic algoriuGm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  126: IBam a genntic algoriAhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  127: INam a gendtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  128: Inam a genMtic algo!ithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  129: I0am a gen8tic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  130: I0am a genntic ,lgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  131: IRam a gendtic ylgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  132: IYam a DmnUtic algorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  133: I0am a genvtic3algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  134: IRam a aenUtic akgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  135: I7am a gencticPalgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  136: IBam a genntic algoriVhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  137: I0am a gendtic algoritGm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  138: I am aDgenhtic algorithm3 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  139: I am a genhtic aleorithm3 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  140: Iaam a gengtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  141: I0am a genKtic Elgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  142: I0am a genhtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  143: Iaam a genstic awgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  144: Iwam a genntic algorithmw 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  145: I am . gennt6c algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  146: Iaam a genKticvalgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  147: I7am a genVtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  148: Iaam a genKtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  149: I am a g?nKtic  lgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  150: IYam a genOtic flgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  151: Ieam a genhtic algorMthK! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  152: I5am a gendtic Elgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  153: I5am a gendtic flgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  154: Igam a gMnEtic Elgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  155: I0am a genVtic ElgorithJ! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  156: I a? a gen.ticPalgorithB! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  157: I5am a gennticOalgorithj! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  158: h am a gen9ti5 algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  159: I amUa gen9tic klgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  160: I am a gennt0caalgprithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  161: hCamUa gen.tic algorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  162: I7am a gKnSticAalgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  163: I am a gene,ic algoritsmK 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  164: ImCm a gen9tic Glgorithm! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  165: I amha g5netdc algorithmQ 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  166: I5amva genetic flgorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  167: I1am x genetic algoZithu! 	|| Max Fitness: 441
# [19-06-2025|23:49:44] Generation  168: I am a genOtic aljoriOhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  169: I am a genOtiG algorithd! 	|| Max Fitness: 484
# [19-06-2025|23:49:44] Generation  170: I am a genebic algoritsm! 	|| Max Fitness: 529
# [19-06-2025|23:49:44] Generation  171: I.am a genetic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  172: I am a genEtic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  173: I.am a gen9tic algor?thm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  174: rmam a g2netic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  175: I am a ge39tic algoriXhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  176: I am a genbtic Ilgorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  177: I.am a ge.e1ic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  178: I.am a genetic alkorifhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  179: I Zm a g8.etic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  180: I nm a gene1ic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  181: I am a genetic alSorilhw! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  182: I am a g?netic algorithmT 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  183: I am a g?netic algorithmT 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  184: K am a genetic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  185: I Zo a genetic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  186: I a3 a genetic dlMorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  187: I a3 a genetic alMorifhm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  188: Icam a genetic aagorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  189: Icamda genedic algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  190: IKam a g0netac algorithm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  191: IYam T genetic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  192: I am a genrtic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  193: I am aMgenetic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  194: I am a gdnetic algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  195: I dm aFgenetic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  196: I Am a genetic alcorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  197: I am a genetic algorithm6 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  198: I aF a genegic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  199: S am a gznetic algori4hm! 	|| Max Fitness: 484
# [19-06-2025|23:49:45] Generation  200: I!am a genFtic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  201: I am a genetic vlgorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  202: I um a genStic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  203: I am a genetic al9orithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  204: I am aVgHnetic algorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  205: I am a genPtic Ulgorithm! 	|| Max Fitness: 529
# [19-06-2025|23:49:45] Generation  206: I am a genetiO algorithm! 	|| Max Fitness: 576
# [19-06-2025|23:49:45] Generation  207: I am a genetic algorithm! 	|| Solved!
